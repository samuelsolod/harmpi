# %% [markdown]
# # Torus 2D Problem

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Open harm_sript.py

# %%
#exec(open('/Users/samuelsolod/pythonREU/harmpi/harm_script.py').read())
# %run -i harm_script.py

# %% [markdown]
# ### rho = density, uu = contravariant gas 4-velocity, gdet = square root of the negative of metric determinant

# %% [markdown]
# ### Get shapes of variables.

# %%
print(f'Shape rho = {np.shape(rho)}')
print(f'Shape uu = {np.shape(uu)}')
print(f'Shape gdet = {np.shape(gdet)}')
print(f'Shape uu_radial = {np.shape(uu_radial)}')
# Out:
# Shape rho = (256, 128, 1)
# Shape uu = (4, 256, 128, 1)
# Shape gdet = (256, 128, 1)
# Shape uu_radial = (256, 128, 1)

# %% [markdown]
# ### Find $\dot{M}$ for each time step.

# %%
total_dumps = 220
mass_accretion_list = []
time_values = []

for i in range(total_dumps + 1):
    dump_number = f'{i:03}'
    rd('dump' + dump_number)
        
    # Pull the radial component of the contravariant 4-velocity for mass acretian rate computation. 
    uu_radial = uu[1,:,:,:]
    integrand = -rho * uu_radial * gdet
    # .squeeze is used to remove the 1 phi dimention. 
    integrand = np.squeeze(integrand)

    theta_min = 0 
    theta_max = 2 * np.pi 
    theta = np.linspace(theta_min, theta_max, 128)

    mass_accretion = np.trapz(integrand, x=theta)
    mass_accretion_list.append(mass_accretion)
    time_values.append(t)
    #output.write(f'{mass_accretion},{t}\n')

df = pd.DataFrame(mass_accretion_list).transpose()
df.columns = time_values
df.to_csv('torus2D.csv', index=False)

# %% [markdown]
# ### Spacetime diagrams of $\dot{M}$.

# %%
data = df.loc[:,0]
#print(np.size(data))
#print(print(r[:,0]))
plt.plot(np.log(r[:,0]), np.log(data))
#plco(np.log10(rho),xy=1,xmax=100,ymax=50,cb=True)
# Out:
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# ...

# %% [markdown]
# ### Make a movie.

# %%
mkmov_simple(starti = 0,endi = 220)
import subprocess

command = "ffmpeg -i frame%03d.png -vcodec mpeg4 -qmax 5 movie.mp4"
subprocess.run(command, shell=True, check=True)
# Out:
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# findfont: Font family 'stix' not found.
# ...
